# %%
import pandas as pd
import numpy as np
import os
import sklearn

# %% [markdown]
# ## Global VARS

# %%
PAD_TOKEN = '<PAD>'
UNFREQ_TOKEN= '<UNF>'

# %%
data_path = 'data/raw_df/adressa_raw.csv'

# %%
news_df = pd.read_csv(data_path)

# %%
news_df.head().T
# Out:
#                                                                  0  \
# id                        fcc01a7a1a7f7092a2da6b9c5186fdef421c8ab6
# url              http://www.adressa.no/nyheter/sortrondelag/201...
# site                                                    adressa.no
# adressa-access                                                free
# author_1st                                             pål solberg
# publishtime                               2016-03-02T14:58:31.000Z
# created_at_ts                                        1456930711000
# text_highlights  - Dette er ingen lekeplass | To barn ble obser...
# concepts                                             politiet,barn
# entities                                     twitter,frøyatunnelen
# locations                                          frøya,trøndelag
# persons                                                        NaN
# category0                                                  nyheter
# category1                                     nyheter|sortrondelag
# category2                                                      NaN
# keywords         utenriks,innenriks,trondheim,E6,midtbyen,bybra...
#
#                                                                  1  \
# id                        e1c14c3f599c9764a003740b9959c4e6f2fbc8e3
# url              http://www.adressa.no/bil/veteran/article80867...
# site                                                    adressa.no
# adressa-access                                                free
# author_1st                                                     NaN
# publishtime                               2007-02-21T07:19:00.000Z
# created_at_ts                                        1172042340000
# text_highlights  Trondheim fylles med veteranbiler | Midtsommer...
# concepts         veteranbiler,trondheim,kjøre,bil,nobel årgang,...
# entities         royal garden hotel,per ramsøskar,granåsen,dats...
# locations                              skottland,trondheim,bentley
# persons            lykkens portal,austin seven,austin seven chummy
# category0                                                      bil
# category1                                              bil|veteran
# category2                                                      NaN
# keywords         nyheter,trondheim,ukeadressa,eadressa,skatteli...
#
#                                                                  2  \
# id                        6a0612e60690288a776834811004ce133f326cee
# url              http://www.adressa.no/kultur/2015/11/06/Histor...
# site                                                    adressa.no
# adressa-access                                                free
# author_1st                                          annemona grann
# publishtime                               2015-11-06T20:41:20.000Z
# created_at_ts                                        1446842480000
# text_highlights  - Historiene er nesten for utrolige | - Jeg ta...
# concepts         valg,mennesker,unge mennesker,temaer,ekstreme ...
# entities         hitler,festningen,individets,jugoslavia,hipp,t...
# locations                          trondheim,oslo,wannsee,new york
# persons          vebjørn sand,joseph schultz,sophia loren,peder...
# category0                                                   kultur
# category1                                                      NaN
# category2                                                      NaN
# keywords                           Kristiansten festning,Trondheim
#
#                                                                  3  \
# id                        13eb96b4cfbbc5954c54a75737afcac5ccc61779
# url              http://www.adressa.no/nyheter/trondheim/articl...
# site                                                    adressa.no
# adressa-access                                                free
# author_1st                                      elin fosshaug olsø
# publishtime                               2005-10-29T14:28:40.000Z
# created_at_ts                                        1130596120000
# text_highlights  Bilister aggressive mot trafikkaksjon | En var...
# concepts         brå u-sving,bilister aggressive,trafikken,bil,...
# entities         obs,sandmoen,tiller vel ingebrigt storli,østre...
# locations                                                      NaN
# persons                berg hansen,trond imset,solfrid berg hansen
# category0                                                  nyheter
# category1                                        nyheter|trondheim
# category2                                                      NaN
# keywords         utenriks,innenriks,trondheim,E6,midtbyen,bybra...
#
#                                                                  4
# id                        b40a30877124510cf65683b6c9391d927e20f89d
# url              http://www.adressa.no/forbruker/hjem/article15...
# site                                                    adressa.no
# adressa-access                                                free
# author_1st                                          ann iren bævre
# publishtime                               2010-08-06T10:13:05.000Z
# created_at_ts                                        1281089585000
# text_highlights  Fyll på med småbord | Det skal være kos og far...
# concepts                                            småbord,bordet
# entities         tray,offecct,penny og wishbone,established,wis...
# locations                                          milano,hay,bend
# persons                                                toan nguyen
# category0                                                forbruker
# category1                                           forbruker|hjem
# category2                                                      NaN
# keywords         nyheter,trondheim,ukeadressa,eadressa,skatteli...

# %% [markdown]
# # Process features

# %%
def get_categ_encoder_from_values(values, include_pad_token=True, include_unfrequent_token=False):
    encoder_values = []
    if include_pad_token:
        encoder_values.append(PAD_TOKEN)
    if include_unfrequent_token:
        encoder_values.append(UNFREQ_TOKEN)
    encoder_values.extend(values)
    encoder_ids = list(range(len(encoder_values)))
    encoder_dict = dict(zip(encoder_values, encoder_ids))
    return encoder_dict

def encode_categ_feature(value, encoder_dict):
    if value in encoder_dict:
        return encoder_dict[value]
    else:
        return encoder_dict[UNFREQ_TOKEN]

def transform_categorical_column(series, encoder):
    return series.apply(lambda x: encode_categ_feature(x, encoder))

def get_encoder_from_freq_values(series, min_freq=100):
    freq_values_counts_df = get_freq_values(series, min_freq=min_freq)
    encoder = get_categ_encoder_from_values(freq_values_counts_df[freq_values_counts_df.columns[0]].unique(), include_unfrequent_token=True)    
    return encoder

def get_freq_values(series, min_freq=100):
    flatten_values_counts = series.groupby(series).size()
    return flatten_values_counts[flatten_values_counts >= min_freq].sort_values(ascending=False).reset_index(name='count')

def comma_sep_values_to_list(value):
    return list([y.strip() for y in value.split(',') if (y.strip() != '')])

# %% [markdown]
# ### ID encoding

# %%
id_enc = get_categ_encoder_from_values(news_df['id'])
transform_categorical_column(news_df['id'], id_enc)
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 73303    73304
# 73304    73305
# 73305    73306
# 73306    73307
# 73307    73308
# Name: id, Length: 73308, dtype: int64

# %% [markdown]
# ### Category encoder

# %%
category0_encoder = get_categ_encoder_from_values(news_df['category0'].unique())
print(f'Category0 - unique count {len(category0_encoder)}')
news_df['category0_encoded'] = transform_categorical_column(news_df['category0'], category0_encoder)

category0_class_weights = sklearn.utils.class_weight.compute_class_weight('balanced', classes=news_df['category0_encoded'].unique(), y=news_df['category0_encoded'])
print(f'Category0 weights: {category0_class_weights}')
# Out:
# Category0 - unique count 41
# Category0 weights: [4.57717283e-02 3.07500000e+00 2.42068419e-01 7.26397146e-01
#  4.08173719e+00 6.74034572e-01 2.45046129e-01 3.40018553e+00
#  4.26209302e+01 2.34360614e+00 2.92529928e-01 2.54541667e+01
#  2.00733844e+00 1.32612156e+00 5.11927374e+00 4.77265625e+00
#  5.98921569e+00 1.30907143e+01 2.90904762e+01 1.36768657e+01
#  1.66609091e+02 6.31965517e+01 7.41983806e+00 3.66540000e+02
#  2.90904762e+01 7.33080000e+01 9.16350000e+01 2.65608696e+01
#  2.61814286e+02 4.07266667e+01 1.22180000e+02 1.83270000e+03
#  9.16350000e+02 9.16350000e+02 1.83270000e+03 1.83270000e+03
#  6.10900000e+02 1.83270000e+03 9.16350000e+02 1.83270000e+03]

# %%
category1_encoder = get_categ_encoder_from_values(news_df['category1'].unique())
news_df['category1_encoded'] = transform_categorical_column(news_df['category1'], category1_encoder)
category1_class_weights = sklearn.utils.class_weight.compute_class_weight('balanced', classes=news_df['category1_encoded'].unique(), y=news_df['category1_encoded'])
# Out:
# Category1 - unique count 128
# %% [markdown]
# ### Author Encoder (must remove infrequent authors due to the "meninger" section)

# %%
author_encoder = get_encoder_from_freq_values(news_df['author_1st'], min_freq=20)
news_df['author_encoded'] = transform_categorical_column(news_df['author_1st'], author_encoder)

# %%
 #Converting values separated by "," to lists
#news_df['keywords'] = news_df['keywords'].apply(comma_sep_values_to_list)
news_df['concepts'] = news_df['concepts'].apply(comma_sep_values_to_list)
news_df['entities'] = news_df['entities'].apply(comma_sep_values_to_list)
news_df['locations'] = news_df['locations'].apply(comma_sep_values_to_list)
news_df['persons'] = news_df['persons'].apply(comma_sep_values_to_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-226397339ed0> in <module>
#       1 #Converting values separated by "," to lists
#       2 #news_df['keywords'] = news_df['keywords'].apply(comma_sep_values_to_list)
# ----> 3 news_df['concepts'] = news_df['concepts'].apply(comma_sep_values_to_list)
#       4 news_df['entities'] = news_df['entities'].apply(comma_sep_values_to_list)
#       5 news_df['locations'] = news_df['locations'].apply(comma_sep_values_to_list)
#
# ~/PycharmProjects/MasterThesisAdressa/venv/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-166-07be13bf4464> in comma_sep_values_to_list(value)
#      29
#      30 def comma_sep_values_to_list(value):
# ---> 31     return list([y.strip() for y in value.split(',') if (y != np.nan and y.strip() != '')])
#
# AttributeError: 'float' object has no attribute 'split'

# %%
news_df.loc[news_df['concepts'].isna()]
# Out:
#                                              id  \
# 16     ec39b8188ab20ea4d2c54719d8f0b8fdd4b0d922
# 20     1f9f2e659eb5488b54457b44773c38e894b62180
# 104    31fe9e457e82b8fd257c27827eb9f0325319cff6
# 114    4070f85cf4952e0e2d1b89d89c569a22ae07ecb5
# 173    a8d451cb414735f4ce4d82ea28e4c484ea25168d
# ...                                         ...
# 72996  25593a1d583001d42191a8d5c4afd924e86079bc
# 73058  c54979a72545b88ef7b9d047d869e68d941d59ff
# 73187  1bac4b262e513826ac3236c2831a640618863caf
# 73214  9936e8f376fe0a57d96050d575265518152b0105
# 73255  1e182ced622adc4285cbddd2db2b21216fe854b3
#
#                                                      url        site  \
# 16     http://www.adressa.no/nyheter/utenriks/article...  adressa.no
# 20     http://www.adressa.no/incoming/2017/03/04/Her-...  adressa.no
# 104    http://www.adressa.no/nyheter/trondheim/articl...  adressa.no
# 114      http://www.adressa.no/pluss/article10774251.ece  adressa.no
# 173       http://www.adressa.no/nyheter/article98748.ece  adressa.no
# ...                                                  ...         ...
# 72996  http://www.adressa.no/pluss/2017/01/23/Se-bild...  adressa.no
# 73058  http://www.adressa.no/nyheter/kuriosa/article6...  adressa.no
# 73187    http://www.adressa.no/video/article12008127.ece  adressa.no
# 73214  http://www.adressa.no/meninger/2017/05/27/Sjef...  adressa.no
# 73255  http://www.adressa.no/pluss/meninger/2016/08/1...  adressa.no
#
#       adressa-access         author_1st               publishtime  \
# 16              free                ntb  2015-02-16T08:41:21.000Z
# 20              free      richard sagen  2017-03-04T07:16:26.000Z
# 104             free                NaN  2004-04-23T19:05:02.000Z
# 114       subscriber  stein arne sæther  2015-03-21T07:03:13.000Z
# 173             free      tone almhjell  2002-08-26T13:40:35.000Z
# ...              ...                ...                       ...
# 72996     subscriber   rune petter ness  2017-01-23T05:15:22.000Z
# 73058           free       yngve bergli  2012-12-08T12:17:48.000Z
# 73187           free                NaN  2016-01-09T00:14:53.000Z
# 73214           free   kjetil kroksæter  2017-05-27T14:33:55.000Z
# 73255     subscriber      terje eidsvåg  2016-08-12T08:28:44.000Z
#
#        created_at_ts                                    text_highlights  \
# 16     1424076081000  EU kunngjør ny sanksjonsliste | Brussel (NTB):...
# 20     1488611786000  Her er Adresseavisens beste bilder fra ski-vm ...
# 104    1082747102000  Dette er Revolt Technology | ReVolt Technology...
# 114    1426921393000  Det meste gikk galt da Norge plutselig fikk kr...
# 173    1030369235000  Redningsmann | Publisert: 26.08.2002 14:40  Si...
# ...              ...                                                ...
# 72996  1485148522000  Se bildeserien fra «råtne» Britannia |  | Se b...
# 73058  1354969068000  Her er lesernes pepperkakehus | Se bildene. | ...
# 73187  1452298493000  Høydepunkter fra Nyttårskonserten | Se kulturm...
# 73214  1495895635000  Kjenner du den brautende, høyrøstede typen som...
# 73255  1470990524000  Et forsvar for de innadvendte - som Van Morris...
#
#       concepts                                           entities  \
# 16         NaN                    arkadij bakhin,anatolij antonov
# 20         NaN                                     adresseavisens
# 104        NaN  sinvent og viking venture,eiendom,næringsforen...
# 114        NaN                                                NaN
# 173        NaN                                                NaN
# ...        ...                                                ...
# 72996      NaN                                          britannia
# 73058      NaN                                                NaN
# 73187      NaN                       nyttårskonserten,olavshallen
# 73214      NaN                                                NaN
# 73255      NaN                                                NaN
#
#                    locations  \
# 16            ukraina,europa
# 20                     lahti
# 104    belgia,trondheim,oslo
# 114           norge,tyskland
# 173                      NaN
# ...                      ...
# 72996                    NaN
# 73058                    NaN
# 73187                    NaN
# 73214                    NaN
# 73255                    NaN
#
#                                                  persons category0  \
# 16                                                   NaN   nyheter
# 20                                                   NaN  incoming
# 104    erik hagen,trygve burchardt,nils kristian nakstad   nyheter
# 114                                                  NaN     pluss
# 173                                                  NaN   nyheter
# ...                                                  ...       ...
# 72996                                                NaN     pluss
# 73058                                                NaN   nyheter
# 73187                                           astrid s     video
# 73214                                                NaN  meninger
# 73255                                       van morrison     pluss
#
#                category1 category2  \
# 16      nyheter|utenriks       NaN
# 20                   NaN       NaN
# 104    nyheter|trondheim       NaN
# 114                  NaN       NaN
# 173                  NaN       NaN
# ...                  ...       ...
# 72996                NaN       NaN
# 73058    nyheter|kuriosa       NaN
# 73187                NaN       NaN
# 73214                NaN       NaN
# 73255     pluss|meninger       NaN
#
#                                                 keywords  category0_encoded  \
# 16     [utenriks, innenriks, trondheim, E6, midtbyen,...                  1
# 20     [nyheter, trondheim, ukeadressa, eadressa, ska...                  8
# 104    [utenriks, innenriks, trondheim, E6, midtbyen,...                  1
# 114    [pluss, eadressa, ukeadressa, digitalt, arkiv,...                  7
# 173    [utenriks, innenriks, trondheim, E6, midtbyen,...                  1
# ...                                                  ...                ...
# 72996  [pluss, eadressa, ukeadressa, digitalt, arkiv,...                  7
# 73058  [utenriks, innenriks, trondheim, E6, midtbyen,...                  1
# 73187  [nyheter, trondheim, ukeadressa, eadressa, ska...                 15
# 73214   [Kommentar, USA, Donald Trump, Kjetil Kroksæter]                  6
# 73255  [Van Morrison, Bruce Springsteen, Lars Amund V...                  7
#
#        category1_encoded  author_encoded
# 16                     7               2
# 20                     3               1
# 104                    4               1
# 114                    3              80
# 173                    3             253
# ...                  ...             ...
# 72996                  3             235
# 73058                 45              61
# 73187                  3               1
# 73214                  3              91
# 73255                 22              11
#
# [1787 rows x 19 columns]
